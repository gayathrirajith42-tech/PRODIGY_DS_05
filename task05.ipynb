# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathrirajith42-tech/PRODIGY_DS_05/blob/main/task05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8df1a9f5-682e-4668-93e3-0c8852709460" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8df1a9f5-682e-4668-93e3-0c8852709460">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_excel("Road Accident Data.xlsx")
print(df.columns)
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type'],
#       dtype='object')

# %%
# Display first 5 rows
print(df.head())
# Out:
#   Accident_Index Accident Date Day_of_Week          Junction_Control  \
# 0  200901BS70001    2021-01-01    Thursday  Give way or uncontrolled
# 1  200901BS70002    2021-01-05      Monday  Give way or uncontrolled
# 2  200901BS70003    2021-01-04      Sunday  Give way or uncontrolled
# 3  200901BS70004    2021-01-05      Monday       Auto traffic signal
# 4  200901BS70005    2021-01-06     Tuesday       Auto traffic signal
#
#            Junction_Detail Accident_Severity   Latitude  \
# 0  T or staggered junction           Serious  51.512273
# 1               Crossroads           Serious  51.514399
# 2  T or staggered junction            Slight  51.486668
# 3  T or staggered junction           Serious  51.507804
# 4               Crossroads           Serious  51.482076
#
#         Light_Conditions Local_Authority_(District) Carriageway_Hazards  ...  \
# 0               Daylight     Kensington and Chelsea                 NaN  ...
# ...

# %%
# Missing values
print(df.isnull().sum())
# Out:
# Accident_Index                     0
# Accident Date                      0
# Day_of_Week                        0
# Junction_Control                   0
# Junction_Detail                    0
# Accident_Severity                  0
# Latitude                           0
# Light_Conditions                   0
# Local_Authority_(District)         0
# Carriageway_Hazards           302549
# Longitude                          0
# Number_of_Casualties               0
# Number_of_Vehicles                 0
# Police_Force                       0
# Road_Surface_Conditions          317
# Road_Type                       1534
# Speed_limit                        0
# Time                              17
# Urban_or_Rural_Area                0
# Weather_Conditions              6057
# Vehicle_Type                       0
# dtype: int64

# %%
df['Accident_Severity'].value_counts()
# Out:
# Accident_Severity
# Slight     263280
# Serious     40740
# Fatal        3904
# Fetal          49
# Name: count, dtype: int64

# %%
df['Accident_Severity'].value_counts().plot(kind='bar')
plt.title('Accident Severity Distribution')
plt.xlabel('Severity')
plt.ylabel('Count')
plt.show()

# %%
df['Weather_Conditions'].value_counts().head(10).plot(kind='bar')
plt.title('Weather Conditions During Accidents')
plt.show()

# %%
df['Road_Surface_Conditions'].value_counts().plot(kind='bar')
plt.title('Road Surface Conditions')
plt.show()

# %%
df["Hour"] = df["Time"].apply(lambda x: x.hour if pd.notnull(x) else None)

# %%
df[["Time","Hour"]].head(10)
# Out:
#        Time  Hour
# 0  15:11:00  15.0
# 1  10:59:00  10.0
# 2  14:19:00  14.0
# 3  08:10:00   8.0
# 4  17:25:00  17.0
# 5  11:48:00  11.0
# 6  13:58:00  13.0
# 7  13:18:00  13.0
# 8  12:15:00  12.0
# 9  09:52:00   9.0

# %%
df['Hour'].value_counts().sort_index().plot(kind='line')
plt.title('Accidents by Hour')
plt.show()

# %%
df['Accident_Severity'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Severity Percentage')
plt.ylabel('')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Accident_Index', 'Accident Date', 'Day_of_Week', 'Junction_Control',
#        'Junction_Detail', 'Accident_Severity', 'Latitude', 'Light_Conditions',
#        'Local_Authority_(District)', 'Carriageway_Hazards', 'Longitude',
#        'Number_of_Casualties', 'Number_of_Vehicles', 'Police_Force',
#        'Road_Surface_Conditions', 'Road_Type', 'Speed_limit', 'Time',
#        'Urban_or_Rural_Area', 'Weather_Conditions', 'Vehicle_Type', 'Hour'],
#       dtype='object')
